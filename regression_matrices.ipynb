# %% [markdown]
# ![{5E44528C-B81A-4A12-93C4-17EBD4EEFEBC}.png](attachment:{5E44528C-B81A-4A12-93C4-17EBD4EEFEBC}.png)

# %% [markdown]
# ![{E9CC3E13-9317-4CBA-90D7-7660A131F169}.png](attachment:{E9CC3E13-9317-4CBA-90D7-7660A131F169}.png)

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df["cgpa"],df["package"])

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()   
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df["cgpa"],df["package"])
plt.plot(x_train,lr.predict(x_train),color="red")

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
y_pred = lr.predict(x_test)

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean Squared Error: 0.08417638361329656
# R^2 Score: 0.7730984312051673
# Mean Absolute Error: 0.23150985393278373
# RMSE 0.2901316659954521

# %%
r2=r2_score(y_test, y_pred)
x_test.shape
# Out:
# (40, 1)

# %%
1-(1-r2)*(40-1)/(40-1-1)
# Out:
# 0.7671273372895138

# %%
new=df.copy()
new["Random_feature"]=np.random.random(200)
new=new[["cgpa","Random_feature","package"]]
new.head()
# Out:
#    cgpa  Random_feature  package
# 0  6.89        0.589188     3.26
# 1  5.12        0.855054     1.98
# 2  7.82        0.846015     3.25
# 3  7.42        0.605997     3.67
# 4  6.94        0.701074     3.57

# %%
plt.scatter(new["Random_feature"],new["package"],color="red")

# %%
x=new.iloc[:,0:2]
y=new.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)

# %%
print("r2_score", r2_score(y_test, y_pred))
r2=r2_score(y_test, y_pred)
# Out:
# r2_score 0.775338109829947

# %%
1-((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.763194223874809
